# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
players<-read_csv("players.csv")
players
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# 10  Veteran     TRUE
# 11  Veteran     TRUE
# 12  Pro         TRUE
# 13  Beginner    TRUE
# 14  Amateur     TRUE
# 15  Veteran     TRUE
# 16  Amateur    FALSE
# 17  Beginner    TRUE
# 18  Amateur     TRUE
# 19  Amateur     TRUE
# 20  Regular     TRUE
# 21  Regular     TRUE
# 22  Amateur    FALSE
# 23  Beginner    TRUE
# 24  Beginner    TRUE
# 25  Amateur     TRUE
# ...

# %%
experience_count<-players|>
group_by(experience)|>
count()

experience_percentage<-experience_count|>
mutate(percentage=n/196*100)
experience_percentage

subscribe_count<-players|>
group_by(subscribe)|>
count()

subsribe_percentage<-subscribe_count|>
mutate(percentage=n/196*100)
subsribe_percentage

gender_count<-players|>
group_by(gender)|>
count()

gender_percentage<-gender_count|>
mutate(percentage=n/196*100)
gender_percentage

mean_played_time<-players|>
summarize(Mean_Played_Time=mean(played_hours, na.rm=TRUE))
mean_played_time

mean_age<-players|>
summarize(Mean_Age=mean(Age, na.rm=TRUE))
mean_age
# Out:
#   experience n  percentage
# 1 Amateur    63 32.142857
# 2 Beginner   35 17.857143
# 3 Pro        14  7.142857
# 4 Regular    36 18.367347
# 5 Veteran    48 24.489796
#   subscribe n   percentage
# 1 FALSE      52 26.53061
# 2  TRUE     144 73.46939
#   gender            n   percentage
# 1 Agender             2  1.0204082
# 2 Female             37 18.8775510
# 3 Male              124 63.2653061
# 4 Non-binary         15  7.6530612
# 5 Other               1  0.5102041
# 6 Prefer not to say  11  5.6122449
# 7 Two-Spirited        6  3.0612245
#   Mean_Played_Time
# 1 5.845918
#   Mean_Age
# 1 20.52062

# %%
# Out:
# Warning message in geom_histogram(identity = stat):
# “Ignoring unknown parameters: `identity`”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# In this project, we were given two sets of data collected by students from the Computer Science Department at UBC on Microsoft players in the server they set up. The first dataset, players.csv, contains information on 196 players. The categorical data collected includes experience level, subscription status, email, name, and gender, while the numerical data includes hours played and age.
# The players in these servers have a mean age of 20.5 years; among all 196 players, 73.5% subscribed to the game. The gender distribution of the players is as follows: 63.27% male, 18.87% female, and 17.83% preferred not to say or identify as agender, non-binary, two-spirited, or other.
# Regarding player experience levels, 32% are Amateurs, 17% are Beginners, 7% are Pros, 18% are Regulars, and 24% are Veterans.
#
# The information collected in the first set of data did not seem to have an issue, they have provided us with basic information that could help to reveal the type of players they are in the later part of our analysis. However, something I noticed is that a lot of the players had no playtime recorded at all. Additionally, in the second set of data, there might be an issue with the way playing time is recorded. In this data set, each observation is tied to an email that is associated with a player listed in the players.csv data, however, it might be hard to identify one by one which the player is. In addition, the original start time and end time collected did not appear to directly reflect conventional time, we might need to further wrangle it to convert it to conventional time.
#
# In this project, I wish to focus on Question 2. The question that I have formulated is can the experience level of the players help predict their player hours in the players.csv dataset?
#
# I will be using classification to classify players depending on how many games they played, from there I will be able to associate the type of players with their experience level.

# %%
sessions<-read_csv("sessions.csv")
sessions
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      hashedEmail
# 1    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3    f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 7    fd6563a4e0f6f4273580e5fedbd8dda64990447aea5a33cbb5e894a3867ca44d
# 8    ad6390295640af1ed0e45ffc58a53b2d9074b0eea694b16210addd44d7c81f83
# ...
